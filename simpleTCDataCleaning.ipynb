# %%
import numpy as np
#in case we need to repeat experiment
np.random.seed(255)

import pandas as pd
pd.options.display.max_rows = 25

import matplotlib.pyplot as plt
plt.style.use('classic')

from IPython.display import display, HTML

import seaborn as sns
sns.set()

# %%
df = pd.read_csv('NCDB_1999_to_2016.csv', engine = 'python')
display(df)
print(df.index.name)
print(df.columns.name)
print(df.columns)
# Out:
#          C_YEAR C_MNTH C_WDAY C_HOUR  C_SEV C_VEHS C_CONF C_RCFG C_WTHR  \
# 0          1999     01      1     20      2     02     34     UU      1
# 1          1999     01      1     20      2     02     34     UU      1
# 2          1999     01      1     20      2     02     34     UU      1
# 3          1999     01      1     08      2     01     01     UU      5
# 4          1999     01      1     08      2     01     01     UU      5
# 5          1999     01      1     17      2     03     QQ     QQ      1
# 6          1999     01      1     17      2     03     QQ     QQ      1
# 7          1999     01      1     17      2     03     QQ     QQ      1
# 8          1999     01      1     17      2     03     QQ     QQ      1
# 9          1999     01      1     15      2     01     04     UU      1
# 10         1999     01      1     15      2     01     04     UU      1
# 11         1999     01      1     14      2     02     31     UU      3
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6486819    2016     12      7     UU      2     01     03     01      1
# 6486820    2016     12      7     12      2     02     21     01      4
# 6486821    2016     12      7     12      2     02     21     01      4
# 6486822    2016     12      7     12      2     02     21     01      4
# 6486823    2016     12      7     12      2     02     21     01      4
# 6486824    2016     12      7     06      2     01     04     01      1
# 6486825    2016     UU      U     01      2     01     06     UU      1
# 6486826    2016     UU      U     01      2     01     06     01      U
# 6486827    2016     UU      U     01      2     01     06     01      U
# 6486828    2016     UU      U     00      2     01     02     01      U
# 6486829    2016     UU      U     00      2     01     02     01      U
# 6486830    2016     UU      U     00      2     01     02     01      U
#
#         C_RSUR   ...    V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_ISEV P_SAFE  \
# 0            5   ...        06   1990   01     M    41    11      1     UU
# 1            5   ...        01   1987   01     M    19    11      1     UU
# 2            5   ...        01   1987   02     F    20    13      2     02
# 3            3   ...        01   1986   01     M    46    11      1     UU
# 4            3   ...        NN   NNNN   01     M    05    99      2     UU
# 5            2   ...        01   1984   01     M    28    11      1     UU
# 6            2   ...        01   1991   01     M    21    11      1     UU
# 7            2   ...        01   1991   02     F    UU    13      2     UU
# 8            2   ...        01   1992   01     M    UU    11      2     UU
# 9            5   ...        01   1997   01     M    61    11      1     UU
# 10           5   ...        01   1997   02     F    56    13      2     02
# 11           4   ...        01   1993   01     F    34    11      1     UU
# ...        ...   ...       ...    ...  ...   ...   ...   ...    ...    ...
# 6486819      3   ...        01   2012   01     F    19    11      2     UU
# 6486820      3   ...        01   2012   01     F    44    11      2     02
# 6486821      3   ...        01   2010   01     M    31    11      1     02
# 6486822      3   ...        01   2010   02     F    25    13      2     02
# 6486823      3   ...        01   2010   03     F    01    22      2     02
# 6486824      5   ...        01   2015   01     M    59    11      2     02
# 6486825      Q   ...        14   2003   01     M    29    96      2     01
# 6486826      U   ...        14   2012   01     M    56    96      2     UU
# 6486827      U   ...        14   2012   02     F    49    96      2     UU
# 6486828      3   ...        01   UUUU   01     F    UU    11      1     UU
# 6486829      3   ...        01   UUUU   02     M    20    13      1     UU
# 6486830      3   ...        01   UUUU   03     M    20    23      2     UU
#
#         P_USER   C_CASE
# 0            1      752
# 1            1      752
# 2            2      752
# 3            1      753
# 4            3      753
# 5            1      820
# 6            1      820
# 7            2      820
# 8            1      820
# 9            1      932
# 10           2      932
# 11           1      992
# ...        ...      ...
# 6486819      1  2455499
# 6486820      1  2455500
# 6486821      1  2455500
# 6486822      2  2455500
# 6486823      2  2455500
# 6486824      1  2455661
# 6486825      5  2433817
# 6486826      5  2434290
# 6486827      5  2434290
# 6486828      1  2455733
# 6486829      2  2455733
# 6486830      2  2455733
#
# [6486831 rows x 23 columns]
# None
# None
# Index(['C_YEAR', 'C_MNTH', 'C_WDAY', 'C_HOUR', 'C_SEV', 'C_VEHS', 'C_CONF',
#        'C_RCFG', 'C_WTHR', 'C_RSUR', 'C_RALN', 'C_TRAF', 'V_ID', 'V_TYPE',
#        'V_YEAR', 'P_ID', 'P_SEX', 'P_AGE', 'P_PSN', 'P_ISEV', 'P_SAFE',
#        'P_USER', 'C_CASE'],
#       dtype='object')

# %%
df['P_SEX'] = df['P_SEX'].map({'F': '0', 'M': '1'})

# %%
df['P_SEX']
# Out:
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
# 5          1
# 6          1
# 7          0
# 8          1
# 9          1
# 10         0
# 11         0
#           ..
# 6486819    0
# 6486820    0
# 6486821    1
# 6486822    0
# 6486823    0
# 6486824    1
# 6486825    1
# 6486826    1
# 6486827    0
# 6486828    0
# 6486829    1
# 6486830    1
# Name: P_SEX, Length: 6486831, dtype: object

# %%
#Move the dependent variable to the outside and drop C_CASE column
P_ISEV = df['P_ISEV']
df.drop(columns = ['P_ISEV'], inplace = True)
df['P_ISEV'] = P_ISEV

# %%
#Move the dependent variable to the outside and drop C_CASE column
df.drop(columns = ['C_SEV', 'C_CASE'], inplace = True)

# %%
print(df.columns)
# Out:
# Index(['C_YEAR', 'C_MNTH', 'C_WDAY', 'C_HOUR', 'C_VEHS', 'C_CONF', 'C_RCFG',
#        'C_WTHR', 'C_RSUR', 'C_RALN', 'C_TRAF', 'V_ID', 'V_TYPE', 'V_YEAR',
#        'P_ID', 'P_SEX', 'P_AGE', 'P_PSN', 'P_SAFE', 'P_USER', 'P_ISEV'],
#       dtype='object')

# %%
for col in df.columns:
    impute = df[col].astype('str').str.contains('[^0-9]')
    df[col][impute] = df[col][impute].apply(lambda x: np.nan)
df_no_missing = df.dropna()
df_no_missing = df_no_missing.reset_index(drop=True)
df_no_missing
df_no_missing_first100 = df_no_missing[:100].copy()
# Out:
# C:\Users\pradeep\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_no_missing[:100]
# Out:
#     C_YEAR C_MNTH C_WDAY C_HOUR C_VEHS C_CONF C_RCFG C_WTHR C_RSUR C_RALN  \
# 0     1999     01      1     09     02     34     02      1      1      1
# 1     1999     01      1     09     02     34     02      1      1      1
# 2     1999     01      1     20     01     03     03      1      1      3
# 3     1999     01      1     05     02     01     02      3      2      4
# 4     1999     01      1     05     02     01     02      3      2      4
# 5     1999     01      1     08     03     33     02      4      2      4
# 6     1999     01      1     09     02     01     02      1      1      1
# 7     1999     01      1     14     02     21     02      1      2      1
# 8     1999     01      1     14     02     21     02      1      2      1
# 9     1999     01      1     07     01     04     05      1      5      1
# 10    1999     01      1     13     02     24     03      1      1      1
# 11    1999     01      1     08     02     34     02      1      2      1
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 88    1999     01      1     05     02     21     02      4      3      1
# 89    1999     01      1     05     02     21     02      4      3      1
# 90    1999     01      1     16     01     01     01      1      3      1
# 91    1999     01      1     10     02     21     02      1      3      1
# 92    1999     01      1     10     02     21     02      1      3      1
# 93    1999     01      1     12     02     33     02      1      1      1
# 94    1999     01      1     12     02     33     02      1      1      1
# 95    1999     01      1     09     02     35     02      1      1      1
# 96    1999     01      1     07     02     21     01      1      2      1
# 97    1999     01      1     07     02     21     01      1      2      1
# 98    1999     01      1     07     02     21     01      1      2      1
# 99    1999     01      1     08     02     33     02      3      3      1
#
#     ...   V_ID V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_SAFE P_USER P_ISEV
# 0   ...     01     01   1992   01     0    33    11     02      1      2
# 1   ...     02     01   1992   01     0    70    11     02      1      1
# 2   ...     01     01   1988   01     0    38    11     02      1      2
# 3   ...     01     06   1995   01     1    34    11     02      1      1
# 4   ...     01     06   1995   02     1    30    13     02      2      1
# 5   ...     01     01   1989   01     1    18    11     02      1      2
# 6   ...     01     01   1986   01     0    68    11     02      1      1
# 7   ...     02     01   1990   01     0    28    11     02      1      2
# 8   ...     02     01   1990   02     1    37    13     02      2      2
# 9   ...     01     06   1994   01     0    50    11     02      1      2
# 10  ...     01     01   1992   01     1    20    11     01      1      2
# 11  ...     01     06   1989   01     1    53    11     02      1      2
# ..  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 88  ...     01     01   1987   02     0    23    13     02      2      2
# 89  ...     02     06   1992   01     1    55    11     02      1      1
# 90  ...     01     01   1986   01     1    71    11     02      1      1
# 91  ...     01     07   1995   01     1    37    11     02      1      1
# 92  ...     02     01   1994   01     0    51    11     02      1      2
# 93  ...     01     01   1989   01     1    19    11     02      1      1
# 94  ...     02     01   1984   01     0    43    11     02      1      2
# 95  ...     02     01   1998   01     1    52    11     02      1      2
# 96  ...     01     01   1988   01     0    33    11     02      1      2
# 97  ...     02     01   1989   01     0    19    11     02      1      2
# 98  ...     02     01   1989   02     1    19    13     02      2      2
# 99  ...     01     06   1990   01     1    35    11     02      1      1
#
# [100 rows x 21 columns]

# %%
df
# Out:
#          C_YEAR C_MNTH C_WDAY C_HOUR C_VEHS C_CONF C_RCFG C_WTHR C_RSUR  \
# 0          1999     01      1     20     02     34    NaN      1      5
# 1          1999     01      1     20     02     34    NaN      1      5
# 2          1999     01      1     20     02     34    NaN      1      5
# 3          1999     01      1     08     01     01    NaN      5      3
# 4          1999     01      1     08     01     01    NaN      5      3
# 5          1999     01      1     17     03    NaN    NaN      1      2
# 6          1999     01      1     17     03    NaN    NaN      1      2
# 7          1999     01      1     17     03    NaN    NaN      1      2
# 8          1999     01      1     17     03    NaN    NaN      1      2
# 9          1999     01      1     15     01     04    NaN      1      5
# 10         1999     01      1     15     01     04    NaN      1      5
# 11         1999     01      1     14     02     31    NaN      3      4
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6486819    2016     12      7    NaN     01     03     01      1      3
# 6486820    2016     12      7     12     02     21     01      4      3
# 6486821    2016     12      7     12     02     21     01      4      3
# 6486822    2016     12      7     12     02     21     01      4      3
# 6486823    2016     12      7     12     02     21     01      4      3
# 6486824    2016     12      7     06     01     04     01      1      5
# 6486825    2016    NaN    NaN     01     01     06    NaN      1    NaN
# 6486826    2016    NaN    NaN     01     01     06     01    NaN    NaN
# 6486827    2016    NaN    NaN     01     01     06     01    NaN    NaN
# 6486828    2016    NaN    NaN     00     01     02     01    NaN      3
# 6486829    2016    NaN    NaN     00     01     02     01    NaN      3
# 6486830    2016    NaN    NaN     00     01     02     01    NaN      3
#
#         C_RALN  ...   V_ID V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_SAFE P_USER  \
# 0            3  ...     01     06   1990   01     1    41    11    NaN      1
# 1            3  ...     02     01   1987   01     1    19    11    NaN      1
# 2            3  ...     02     01   1987   02     0    20    13     02      2
# 3            6  ...     01     01   1986   01     1    46    11    NaN      1
# 4            6  ...     99    NaN    NaN   01     1    05    99    NaN      3
# 5            1  ...     01     01   1984   01     1    28    11    NaN      1
# 6            1  ...     02     01   1991   01     1    21    11    NaN      1
# 7            1  ...     02     01   1991   02     0   NaN    13    NaN      2
# 8            1  ...     03     01   1992   01     1   NaN    11    NaN      1
# 9          NaN  ...     01     01   1997   01     1    61    11    NaN      1
# 10         NaN  ...     01     01   1997   02     0    56    13     02      2
# 11           2  ...     01     01   1993   01     0    34    11    NaN      1
# ...        ...  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...
# 6486819      1  ...     01     01   2012   01     0    19    11    NaN      1
# 6486820      1  ...     01     01   2012   01     0    44    11     02      1
# 6486821      1  ...     02     01   2010   01     1    31    11     02      1
# 6486822      1  ...     02     01   2010   02     0    25    13     02      2
# 6486823      1  ...     02     01   2010   03     0    01    22     02      2
# 6486824      1  ...     01     01   2015   01     1    59    11     02      1
# 6486825    NaN  ...     01     14   2003   01     1    29    96     01      5
# 6486826      4  ...     01     14   2012   01     1    56    96    NaN      5
# 6486827      4  ...     01     14   2012   02     0    49    96    NaN      5
# 6486828      1  ...     01     01    NaN   01     0   NaN    11    NaN      1
# 6486829      1  ...     01     01    NaN   02     1    20    13    NaN      2
# 6486830      1  ...     01     01    NaN   03     1    20    23    NaN      2
#
#         P_ISEV
# 0            1
# 1            1
# 2            2
# 3            1
# 4            2
# 5            1
# 6            1
# 7            2
# 8            2
# 9            1
# 10           2
# 11           1
# ...        ...
# 6486819      2
# 6486820      2
# 6486821      1
# 6486822      2
# 6486823      2
# 6486824      2
# 6486825      2
# 6486826      2
# 6486827      2
# 6486828      1
# 6486829      1
# 6486830      2
#
# [6486831 rows x 21 columns]

# %%
df_no_missing_first100
# Out:
#     C_YEAR C_MNTH C_WDAY C_HOUR C_VEHS C_CONF C_RCFG C_WTHR C_RSUR C_RALN  \
# 0     1999     01      1     09     02     34     02      1      1      1
# 1     1999     01      1     09     02     34     02      1      1      1
# 2     1999     01      1     20     01     03     03      1      1      3
# 3     1999     01      1     05     02     01     02      3      2      4
# 4     1999     01      1     05     02     01     02      3      2      4
# 5     1999     01      1     08     03     33     02      4      2      4
# 6     1999     01      1     09     02     01     02      1      1      1
# 7     1999     01      1     14     02     21     02      1      2      1
# 8     1999     01      1     14     02     21     02      1      2      1
# 9     1999     01      1     07     01     04     05      1      5      1
# 10    1999     01      1     13     02     24     03      1      1      1
# 11    1999     01      1     08     02     34     02      1      2      1
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 88    1999     01      1     05     02     21     02      4      3      1
# 89    1999     01      1     05     02     21     02      4      3      1
# 90    1999     01      1     16     01     01     01      1      3      1
# 91    1999     01      1     10     02     21     02      1      3      1
# 92    1999     01      1     10     02     21     02      1      3      1
# 93    1999     01      1     12     02     33     02      1      1      1
# 94    1999     01      1     12     02     33     02      1      1      1
# 95    1999     01      1     09     02     35     02      1      1      1
# 96    1999     01      1     07     02     21     01      1      2      1
# 97    1999     01      1     07     02     21     01      1      2      1
# 98    1999     01      1     07     02     21     01      1      2      1
# 99    1999     01      1     08     02     33     02      3      3      1
#
#     ...   V_ID V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_SAFE P_USER P_ISEV
# 0   ...     01     01   1992   01     0    33    11     02      1      2
# 1   ...     02     01   1992   01     0    70    11     02      1      1
# 2   ...     01     01   1988   01     0    38    11     02      1      2
# 3   ...     01     06   1995   01     1    34    11     02      1      1
# 4   ...     01     06   1995   02     1    30    13     02      2      1
# 5   ...     01     01   1989   01     1    18    11     02      1      2
# 6   ...     01     01   1986   01     0    68    11     02      1      1
# 7   ...     02     01   1990   01     0    28    11     02      1      2
# 8   ...     02     01   1990   02     1    37    13     02      2      2
# 9   ...     01     06   1994   01     0    50    11     02      1      2
# 10  ...     01     01   1992   01     1    20    11     01      1      2
# 11  ...     01     06   1989   01     1    53    11     02      1      2
# ..  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 88  ...     01     01   1987   02     0    23    13     02      2      2
# 89  ...     02     06   1992   01     1    55    11     02      1      1
# 90  ...     01     01   1986   01     1    71    11     02      1      1
# 91  ...     01     07   1995   01     1    37    11     02      1      1
# 92  ...     02     01   1994   01     0    51    11     02      1      2
# 93  ...     01     01   1989   01     1    19    11     02      1      1
# 94  ...     02     01   1984   01     0    43    11     02      1      2
# 95  ...     02     01   1998   01     1    52    11     02      1      2
# 96  ...     01     01   1988   01     0    33    11     02      1      2
# 97  ...     02     01   1989   01     0    19    11     02      1      2
# 98  ...     02     01   1989   02     1    19    13     02      2      2
# 99  ...     01     06   1990   01     1    35    11     02      1      1
#
# [100 rows x 21 columns]

# %%
df_no_missing.to_csv('data01_simple.csv', encoding='utf-8', index=False)
df_no_missing_first100.to_csv('data01_simple_100.csv', encoding='utf-8', index=False)
